# %%
##Ok let's first import pandas

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
##Import data file
df = pd.read_csv('Test_Data.txt')

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=61, step=1)

# %%
dfAll = pd.concat([df,pd.DataFrame({'Voltage':pd.Series(data=3.3*df.Do/2**16,index=range(0,61))})],axis=1)

# %%
print(dfAll.head(5))
# Out:
#     Time     Do   Voltage
# 0  3.055  65488  3.297583
# 1  3.620  65520  3.299194
# 2  3.996  65520  3.299194
# 3  4.376  65488  3.297583
# 4  4.754  65520  3.299194

# %%
dfAll.plot(x='Time',y='Voltage')
plt.grid()
plt.xlabel('Time (sec)')
plt.ylabel('Voltage (V)')
# Out:
# Text(0, 0.5, 'Voltage (V)')
